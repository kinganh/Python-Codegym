# %% [markdown]
# # Mã giả & Lưu đồ giải thuật
#
# ### Lập trình
#
# Lập trình là gì?

# %% [markdown]
# Lập trình là đưa ra những câu lệnh để máy tính thực hiện.
#
# Đưa ra câu lệnh A, trước câu lệnh B thì câu lệnh A sẽ được thực hiện trước.

# %% [markdown]
# ### Thuật toán
#
# Thuật toán là gì?

# %% [markdown]
# Thuật toán là những câu lệnh được đưa ra để giải quyết một vấn đề nào đó.

# %% [markdown]
# ### Mã gỉả
#
# #### Khái niệm:
#
# Mã giả được viết với ngôn ngữ tự nhiên một thuật toán nào đó dùng để giải quyết một vấn đề lập trình.
#
# Mã giả được quy ước chung theo từng nơi làm việc.
#
# Ví dụ:
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (bánh mỳ)
# Nếu (bánh mỳ còn):
#     Đặt (bánh mỳ)
# Ngược lại:
#     Nếu (cơm rang còn):
#         Đăt (cơm sườn)
#     Ngược lại:
#         Đi ngủ

# %% [markdown]
# Nhập (món đó)
# Nếu (món đó còn):
#     Ta đặt món đó
# Ngược lại:
#     Nếu (cơm sườn còn):
#         Ta đặt cơm sườn
#     Ngược lại:
#         Đi ngủ

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (**)
# Nếu (** > 10)
#     Hiển thị (**)
# Ngược lại:
#     Hiển thị ("error")

# %% [markdown]
# Nhập (a)
# Nếu (a > 10):
#     In ra (a là số lón hơn 10)
# Ngược lại:
#     In ra (a là số không lớn hơn 10)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a>0)
#     In ra (a là số dương)
# Ngược lại:
#     Nếu (a == 0)
#     In ra (a là số không âm không dương)
#     Ngược lại:
#     In ra (a là số âm)

# %% [markdown]
# Nhập (a)
# Nếu (a>0):
#     In ra (a là số dương)
# Ngược lại:
#     Nếu (a == 0):
#         In ra (a là số không âm không dương)
#     Ngược lại:
#         In ra (a là số âm)

# %% [markdown]
# ### Lưu đồ giải thuật
#
# Lưu đồ giải thuật là một thuật toán được biểu diễn với dạng lưu đồ
#
# Công cụ vẽ lưu đồ giải thuật: https://draw.io/
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bài tập
#
# <b>Đề bài</b>
#
# Nhập vào nhiệt độ C, chuyển sang độ F rồi in ra màn hình
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (độ C)
# độ F = (độ C)*1.8 + 32
# In ra (độ F)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương tháng này, nếu lương tháng này nhiều hơn 2 triệu thì trừ đi 10% thuế, nếu không thì không trừ.
#
# Hãy tính và in ra lương thực nhận được
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (Lương T5)
# Nếu (Lương T5 > 2.000.000)
# Lương thực nhận = (Lương T5)*0.9
#     In ra (Lương thực nhận)
#         Ngược lại:
#         Lương thực nhận = lương T5
#         In ra (Lương thực nhận)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương thực nhận được tháng này, nếu lương ít hơn 10 triệu, đưa hết cho vợ, nếu lương nhiều hơn 10 triệu, vợ cho 10% lương
#
# Hãy tính và in ra màn hình phần lương mình được nhận
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (Lương T5)
# Nếu (Lương T5 < 10tr)
# Lương mình = 0
# In ra (Lương mình)
#     Ngược lại:
#     Lương mình = (Lương T5)*0.1
#     In ra (Lương mình)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào số điểm văn và điểm toán, tính và in ra điểm trung bình, nếu điểm trung bình lớn hơn 8 thì in ra dòng chữ Học sinh giỏi, ngược lại thì in ra dòng chữ Không phải học sinh giỏi
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (điểm văn)
# Nhập (điểm toán)
# ĐTB = (điểm văn + điểm toán)/2
# In ra (ĐTB)
# Nếu (ĐTB>8)
# In ra (Học sinh giỏi)
#     Ngược lại:
#     In ra (Không phải học sinh giỏi)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra xem số đó có chia hết cho 5 hay không
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# x= a % 5
# Nêu (x ==0)
#     In ra (a chia hết cho 5)
# Ngược lại:
#     In ra (a không chia hết cho 5)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào điểm số, nếu điểm số lớn hơn hoặc bằng 8, in ra dòng chữ Học sinh giỏi, nếu điểm số bé hơn 8 và lớn hơn hoặc bằng 6, in ra dòng chữ chữ học sinh Khá, ngược lại in ra dòng chữ Học sinh trung bình
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (x)
# Nếu (x>8 hoặc x=8)
#     In ra (Học sinh giỏi)
# Ngược lại:
#     Nếu (x>6 hoặc x=6)
#         In ra (Học sinh khá)
#     Ngược lại:
#         In ra(Học sinh TB)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra tính chẳn lẻ và số đó có lớn hơn 10 hay không. (in ra 4 trường hợp: chẳn lớn hơn 10, lẻ lớn hơn 10, chẳn bé hơn hoặc bằng 10, lẻ bé hơn 10)
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (x)
# Nếu (x>10)
#     Nếu (x%2==0):
#         In ra (chẵn lớn hơn 10)
#     Ngược lại:
#         In ra (lẻ lớn hơn 10)
# Ngược lại:
#     Nếu (x%2==0):
#         In ra (chẵn nhỏ hơn hoặc bằng 10)
#     Ngược lại:
#         In ra (lẻ bé hơn 10)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Nhập (x)
Nhập (y)
Nếu x == y:
    In ra "Dự đoán đúng"
Ngược lại:
    In ra "Dự đoán sai"

# %%
from tkinter import *
sc = Tk()
sc.title("MỘT SỐ BÀI TOÁN CƠ BẢN")

giatri_R = IntVar()
giatri_R.set(1)


def click_R():
    if giatri_R.get() == 1:
        et1.config(state= "normal")
        et2.config(state= "disable")
        et3.config(state= "disable")
        et4.config(state= "disable")
    elif giatri_R.get() == 2:
        et1.config(state= 'disable')
        et2.config(state= 'normal')
        et3.config(state= 'disale')
        et4.config(state= 'disable')        
    elif giatri_R.get() == 3:
        et1.config(state= "disable")
        et2.config(state= "disable")
        et3.config(state= "normal")
        et4.config(state= "normal")   
        
def songuyento(a):
    if a < 2:
        return False
    for i in range(2,a):
        if a % i == 0:
            return False
    return True
def sochinhphuong(a):
    cana = a**0.5
    if cana == int(cana):
        return True
    return False

def thuchien():
    chuoi_kq = ""
    if giatri_R.get() == 1:
        n = int(et1.get())
        for i in range(1,n+1):
            if songuyento(i):
                chuoi_kq += str(i) + ","
        chuoi_kq = chuoi_kq[:-2]
    elif giatri_R.get() == 2:
        n = int(et2.get())
        for i in range(1,n+1):
            if sochinhphuong(i):
                chuoi_kq += str(i) + ","
        chuoi_kq = chuoi_kq[:-2]
    elif giatri_R.get() == 3:
        n = int(et3.get())
        m = int(et4.get())
        while n != m:
            if n > m:
                n -= m
            else:
                m -= n
        chuoi_kq = str(n)
    hienthi(chuoi_kq)       
    
def hienthi(s):
    i = 65
    while i < len(s):
        s = s[:i] + '\n'+ s[i:]
        i += 66
    kq.config(text = s)
                
tit = Label(sc, text="CHƯƠNG TRÌNH GIẢI MỘT SỐ BÀI TOÁN CƠ BẢN", fg="red", font=("Arial",14,"bold")).grid(row=1, column=1, columnspan=3, padx=(20,20), pady=(5,20))
R1 = Radiobutton(sc, command=click_R, text="Tìm các số nguyên tố [1-N]",variable=giatri_R, value=1).grid(row=2, column=1, sticky=W, padx=(30,0), pady=(0,20))
R2 = Radiobutton(sc, command=click_R, text="Liệt kê các cố chính phương [1-N]",variable=giatri_R, value=2).grid(row=3, column=1,sticky=W, padx=(30,0), pady=(0,20))
R3 = Radiobutton(sc, command=click_R, text="Tìm UCLN của hai số a,b!", variable=giatri_R, value=3).grid(row=4, column=1,rowspan=2,sticky=W, padx=(30,0))
et1 = Entry(sc).grid(row=2, column=2, pady=(0,20))
et2 = Entry(sc, state="disabled").grid(row=3, column=2, pady=(0,20))
et3 = Entry(sc, state="disabled").grid(row=4, column=2)
et4 = Entry(sc, state="disabled").grid(row=5, column=2)
bt1 = Button(sc, text="Thực hiện", command=thuchien, relief="raised", fg = "blue", font=("Arial,18"), width=8).grid(row=2, column=3, rowspan=2, pady=(0,20))
bt2 = Button(sc, text="Thoát", relief="raised", fg = "red", font=("Arial,18"), width=8).grid(row=3, column=3, rowspan=2)
kq = Label(sc, text="", bg="white", relief="sunken", width=65, height=5, anchor=NW, font=('Courier New',12)).grid(row=6, column=1, rowspan=3, columnspan=3, pady=(20,0))

sc.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\PC\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_10256\4260565376.py", line 16, in click_R
#     et1.config(state= 'disable')
# AttributeError: 'NoneType' object has no attribute 'config'
